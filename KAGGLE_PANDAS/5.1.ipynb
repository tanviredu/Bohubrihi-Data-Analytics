# %%
### importing the wine dataset
### to answer some business query

# %%
import pandas as pd
reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)
pd.set_option("display.max_rows", 5)
from learntools.core import binder; binder.bind(globals())
from learntools.pandas.grouping_and_sorting import *
print("Setup complete.")
# Out:
# Setup complete.

# %%
## what are the most common reviewer in the data set
## that means who vote most in the wine dataset
## the name is the "taster_twitter_handle"
## we have to group basesd on the taster_twitter_handle""
reviews.groupby("taster_twitter_handle").taster_twitter_handle.count()
# Out:
# taster_twitter_handle
# @AnneInVino        3685
# @JoeCz             5147
#                    ...
# @winewchristina       6
# @worldwineguys     1005
# Name: taster_twitter_handle, Length: 15, dtype: int64

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
## we can do it another way
reviews['taster_twitter_handle'].value_counts().sort_values(ascending=False)
# Out:
# taster_twitter_handle
# @vossroger         25514
# @wineschach        15134
#                    ...
# @bkfiona              27
# @winewchristina        6
# Name: count, Length: 15, dtype: int64

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
# Who are the most common wine reviewers in the dataset? Create a `Series` whose index is the `taster_twitter_handle` category from the dataset, and whose values count how many reviews each person wrote.

# %%
# Your code here
reviews_written = reviews.groupby("taster_twitter_handle").taster_twitter_handle.count()
# Check your answer
q1.check()
# Out:
# Correct:
#
#
# ```python
# reviews_written = reviews.groupby('taster_twitter_handle').size()
# ```
# or
# ```python
# reviews_written = reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()
# ```

# %%
q1.hint()
q1.solution()
# Out:
# Hint: Use the `groupby` operation and `size()` (or `count()`).
# Solution:
# ```python
# reviews_written = reviews.groupby('taster_twitter_handle').size()
# ```
# or
# ```python
# reviews_written = reviews.groupby('taster_twitter_handle').taster_twitter_handle.count()
# ```

# %% [markdown]
# ## 2.
# What is the best wine I can buy for a given amount of money? Create a `Series` whose index is wine prices and whose values is the maximum number of points a wine costing that much was given in a review. Sort the values by price, ascending (so that `4.0` dollars is at the top and `3300.0` dollars is at the bottom).

# %%
## you have to find the best wine in a given amount of money
## 1. Create Series
## 2. index will be wine price
## 3. given price the max points of wine
## 4. then sort the wine based on price
max_points_order_by_price = reviews.groupby("price").points.max()
max_points_order_by_price.sort_index()
# Out:
# price
# 4.0       86
# 5.0       87
#           ..
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
## we can fo it another way using the apply() method
def get_max(df):
    max_value = df.points.max()
    return max_value
target = reviews.groupby("price").apply(get_max)
target.sort_index()
# Out:
# price
# 4.0       86
# 5.0       87
#           ..
# 2500.0    96
# 3300.0    88
# Length: 390, dtype: int64

# %%
def find_max_point(df):
    xx = df.points.max()
    return xx
best_rating_per_price = reviews.groupby('price').apply(find_max_point)
best_rating_per_price = best_rating_per_price.sort_index()

# Check your answer
q2.check()
best_rating_per_price
# Out:
# Correct
# price
# 4.0       86
# 5.0       87
#           ..
# 2500.0    96
# 3300.0    88
# Length: 390, dtype: int64

# %%
#q2.hint()
#q2.solution()

# %% [markdown]
# ## 3.
# What are the minimum and maximum prices for each `variety` of wine? Create a `DataFrame` whose index is the `variety` category from the dataset and whose values are the `min` and `max` values thereof.

# %%
## minmum (min) and maximum (max) price for each variety of wine
##1. for each variety we find the max and min price of each group
reviews.groupby("variety").price.agg(["min","max"])
# Out:
#               min   max
# variety
# Abouriou     15.0  75.0
# Agiorgitiko  10.0  66.0
# ...           ...   ...
# Çalkarası    19.0  19.0
# Žilavka      15.0  15.0
#
# [707 rows x 2 columns]

# %%
price_extremes = reviews.groupby("variety").price.agg(['min','max'])

# Check your answer
q3.check()
price_extremes
# Out:
# Correct
#               min   max
# variety
# Abouriou     15.0  75.0
# Agiorgitiko  10.0  66.0
# ...           ...   ...
# Çalkarası    19.0  19.0
# Žilavka      15.0  15.0
#
# [707 rows x 2 columns]

# %%
#q3.hint()
#q3.solution()

# %% [markdown]
# ## 4.
# What are the most expensive wine varieties? Create a variable `sorted_varieties` containing a copy of the dataframe from the previous question where varieties are sorted in descending order based on minimum price, then on maximum price (to break ties).

# %%
## first we have o find the max mean of every variety of the the wine
price_extremes = reviews.groupby("variety").price.agg(['min','max'])
#then we have sort based on min and then max
price_extremes.sort_values(['min','max'],ascending=[False,False])
# Out:
#              min    max
# variety
# Ramisco    495.0  495.0
# Terrantez  236.0  236.0
# ...          ...    ...
# Vital        NaN    NaN
# Zelen        NaN    NaN
#
# [707 rows x 2 columns]

# %%
sorted_varieties = price_extremes.sort_values(['min','max'],ascending=[False,False])

# Check your answer
q4.check()
sorted_varieties
# Out:
# Correct
#              min    max
# variety
# Ramisco    495.0  495.0
# Terrantez  236.0  236.0
# ...          ...    ...
# Vital        NaN    NaN
# Zelen        NaN    NaN
#
# [707 rows x 2 columns]

# %%
#q4.hint()
#q4.solution()

# %% [markdown]
# ## 5.
# Create a `Series` whose index is reviewers and whose values is the average review score given out by that reviewer. Hint: you will need the `taster_name` and `points` columns.

# %%
# 1) group by reviewsers
# 2) and then find the mean of the points
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
#                         ...
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, Length: 19, dtype: float64

# %%
## same
reviews.groupby("taster_name").points.mean()
## same
reviewer_mean_ratings = reviews.groupby("taster_name")['points'].mean()

# Check your answer
q5.check()
reviewer_mean_ratings
# Out:
# Correct
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
#                         ...
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, Length: 19, dtype: float64

# %%
#q5.hint()
#q5.solution()

# %% [markdown]
# Are there significant differences in the average scores assigned by the various reviewers? Run the cell below to use the `describe()` method to see a summary of the range of values.

# %%
reviewer_mean_ratings.describe()

# %% [markdown]
# ## 6.
# What combination of countries and varieties are most common? Create a `Series` whose index is a `MultiIndex`of `{country, variety}` pairs. For example, a pinot noir produced in the US should map to `{"US", "Pinot Noir"}`. Sort the values in the `Series` in descending order based on wine count.

# %%
## multiindex means it will be grouped by multiple parameter
## which countries and varities are msot common
## we group the data based on country and variety and then for each
## group we count the wine .
## but we cant use count . because count on what that
##  we have to use size()
reviews.groupby(['country','variety']).size().sort_values(ascending=False)
# Out:
# country  variety
# US       Pinot Noir            9885
#          Cabernet Sauvignon    7315
#                                ...
# Mexico   Rosado                   1
# Uruguay  White Blend              1
# Length: 1612, dtype: int64

# %%
country_variety_counts = reviews.groupby(['country','variety']).size().sort_values(ascending=False)

# Check your answer
q6.check()
country_variety_counts
# Out:
# Correct
# country  variety
# US       Pinot Noir            9885
#          Cabernet Sauvignon    7315
#                                ...
# Mexico   Rosado                   1
# Uruguay  White Blend              1
# Length: 1612, dtype: int64

# %%
#q6.hint()
q6.solution()
# Out:
# Solution:
# ```python
# country_variety_counts = reviews.groupby(['country', 'variety']).size().sort_values(ascending=False)
# ```

# %% [markdown]
# # Keep going
#
# Move on to the [**data types and missing data**](https://www.kaggle.com/residentmario/data-types-and-missing-values).

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/pandas/discussion) to chat with other learners.*
